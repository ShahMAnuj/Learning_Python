# %%
import pandas as pd

# %%
#just importing our CSV file as a dataframe
df = pd.read_csv("test_spreadsheet.csv")
df
# Out:
#    column1  column2  column3  column4
# 0        1        5        2        3
# 1        3        3        4        8
# 2        4        7        9        2
# 3        5        9       10        4

# %%
#importing our CSV file as a dataframe, while also changing the name of the index column
df = pd.read_csv("test_spreadsheet.csv", index_col="respondent_id")
